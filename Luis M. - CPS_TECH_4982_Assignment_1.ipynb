# %% [markdown]
# # Assignment 1 (100 pts)
#
# <br>
#
# ## Requirements (Colab Environment)
#
# Before submitting your assignment, please follow these steps carefully:
#
# 1. **Non-programming questions**: Provide answers to non-programming questions in either text cells or within code cells using Python comments.
#
# 2. **Run all code cells**: Ensure that every code cell in your notebook has been executed and the output is visible below each corresponding cell.
#
# 3. **Check the output**: Review the outputs for accuracy and completeness. If any errors occur, fix them before submission.
#
# 4. **Save your results**: Once you have run all the cells and checked the outputs, save the notebook with the outputs included. The saved file should show both the code and the outputs. Click on **File** > **Download** > **Download .ipynb**. Save the notebook to your computer, then upload it to Canvas.
#
# 5. **Submission without output will receive a 0**: Any submission that contains only code without visible outputs will automatically receive a grade of 0. Ensure that the notebook you submit includes all outputs from executed cells.
#
# <br>
#
# ## AI Tools Usage Policy
#
# Students are permitted to use AI tools, such as ChatGPT, **only for general purposes**, such as debugging assistance or searching for explanations and help with Python functions. However, **copying assignment questions or code** directly into AI tools to generate answers or solutions is strictly prohibited. This is considered **cheating** and will result in an automatic grade of 0 for the assignment.
#
# Students must also **report the use of any AI tools** in their submission, including:
# - A clear description of which questions or areas were supported by AI.
# - **Adding a comment at the beginning of your text cells or code cells** indicating where AI assistance was used.
#
# - **First violation**: Any student found copying code or assignment questions from AI tools will receive a 0 for that assignment.
# - **Second violation**: A second violation will result in **automatic failure** of the course.
#
# Please ensure your use of AI tools is limited to appropriate, educational purposes, and always credit any assistance received.

# %% [markdown]
# # PART I: Non-Programming Questions

# %% [markdown]
# #### 1. (10 pts) The 8-bit image format is widely used in computer vision. In your own words, explain the following:
#
# 1. The number of intensity levels in an 8-bit grayscale image.
# 2. The range of pixel values in an 8-bit grayscale image.
# 3. What color the minimum value represents.
# 4. What color the maximum value represents.

# %% [markdown]
# Your answers:
# 1. The number of intensity levels in an 8-bit grayscale image is 256. This can be found with L = 2^k where k equals the number of bits and L is the number of intensity levels. When k = 8, the result is 256.
#
#
# 2. The range of pixel values in an 8-bit grayscale image is 0 to 255. With the 8 bits we can represent the 256 values starting from 0 with the absence of light and 255 representing the maximum intensity of light.
#
#
# 3. The minimum value represents black in an image.
#
#
# 4. The maximum value represents white in a grayscale image or full color in an RGB image.

# %% [markdown]
# #### 2. (10 pts) Use **your own words** to explain:
#
# 1. What is spatial resolution in an image? How is it related to the number of pixels?
# 2. What does intensity resolution mean in a digital image? How does it affect the image's appearance?
# 3. For an image with 128 intensity levels, what is its intensity resolution?

# %% [markdown]
# Your answers:
# 1. Spatial resolution in an image is the measure of the smallest discernible detail. It is commonly measured using dots per inch (dpi). A larger spatial resolution means a clearer and sharper display as it measures how densely pixels are packed in a given area. So while the number of pixels can tell us the image size, it doesn't reflect pixel density.
#
#
# 2. The intensity resolution is the smallest discernible change in intensity level. With a higher intensity resolution more shades or colors can be represented, resulting in smoother gradients and greater details.
#
#
# 3. If an image has 128 intensity levels its resolution is 7 bits. This can be found by making k = 7 in the equation 128 = 2^k.

# %% [markdown]
# #### 3. (10 pts) Please calculate the following three types of distances between pixel **p = (3, 4)** and **q = (7, 1)**:
#
# 1. **Euclidean distance $D_{e}$**:
#    $$
#    𝐷ₑ(p, q) = \sqrt{(u - x)^2 + (v - y)^2}
#    $$
#    <br>
#
# 2. **City-block distance $D_{4}$**:
#    $$
#    𝐷₄(p, q) = |u - x| + |v - y|
#    $$
#    <br>
#
# 3. **Chessboard distance $D_{8}$**:
#    $$
#    𝐷₈(p, q) = \max(|u - x|, |v - y|)
#    $$
#    <br>
#
# Please show your calculations and final results for each type of distance.

# %% [markdown]
# Your answers:
#
# x = 3, y = 4
#
# u = 7, v = 1
#
# 1. (7-3)^2 = 16
#
#    (1-4)^2 = 9
#
#    16 + 9 = 25
#
#    square root of 25 is = 5
#
#    Euclidean distance = 5
#
#
# 2. |7-3| = 4
#
#    |1-4| = 3
#
#    4 + 3 = 7
#
#    City-block distance = 7
#
#
# 3. |7-3| = 4
#
#    |1-4| = 3
#
#    max(4,3) = 4
#
#    Chessboard distance = 4

# %% [markdown]
# # PART II: Programming Questions

# %% [markdown]
# #### 4. (15 pts) Load the **grayscale** image **letters-and-objects.tif** into a variable **`letterImg`**. Write Python statements to complete the following tasks:
#
# 1. Display the image. (3 pts)
# 2. Print the height and width of the image. (4 pts)
# 3. Extract a region of interest (RoI) that contains only the triangle in the image. Display the RoI. (8 pts)
#
# **Hints**:
# - You can use either the OpenCV or PIL libraries to load and manipulate the image.
# - Experiment with the coordinates to crop the RoI containing the triangle.

# %%
# import libraries

from google.colab.patches import cv2_imshow
import cv2

from PIL import Image
import matplotlib.pyplot as plt

import numpy as np

# %%
# Q4-1

letterImg = cv2.imread('letters-and-objects.tif', cv2.IMREAD_GRAYSCALE)
cv2_imshow(letterImg)
# Out:
# <PIL.Image.Image image mode=L size=757x757>

# %%
# Q4-2

print("Image Height:", letterImg.shape[0])
print("Image Width:", letterImg.shape[1])
# Out:
# Image Height: 757
# Image Width: 757

# %%
# Q4-3

height = letterImg.shape[0]
width = letterImg.shape[1]

roi = letterImg[height-200:757, width-500:500]

cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=L size=243x200>

# %% [markdown]
# #### 5. (20 pts) Load the **color** image **sunflower.tif** into a variable **`sunflowerImg`**. Write Python statements to complete the following tasks:
#
# 1. Count the total number of pixels in the image. (4 pts)
# 2. Display the following four images in one row: the original image, the red channel, the green channel, and the blue channel. Each sub-figure should have an appropriate title. (8 pts)
# 3. Create a **black** square to cover the center of the sunflower (the black-brown disk flowers). Display the original image and the manipulated image side by side. (8 pts)
#
# **Hints**:
# - Use the PIL library to load and manipulate the image. You need to **convert the loaded image to a numpy array** before calculating its size/shape and extracting individual channels.
# - Consider the order of the three channels when extracting them (Red, Green, Blue).
# - Use the `plt.subplot` function to arrange the display. Feel free to use AI tools to help you understand how it works.
# - By default, plt.imshow() assumes an image has three channels (RGB). To properly display each channel as an image, you need to provide a colormap. For example,
# ```python
# plt.imshow(greenCh, cmap='gray')
# ```

# %%
# Q5-1

sunflowerImg = Image.open('sunflower.tif')

sunflowerImgArray = np.array(sunflowerImg)

print("Total number of pixels:", sunflowerImgArray.size)
# Out:
# Total number of pixels: 1379025

# %%
# Q5-2

plt.figure(figsize=(12, 3))

# Original Image
plt.subplot(1, 4, 1)
plt.imshow(sunflowerImg, cmap='gray')
plt.axis('off')
plt.title('Original Image')

# Red Channel
plt.subplot(1, 4, 2)
redChannel = sunflowerImgArray[:, :, 0]
plt.imshow(redChannel, cmap='gray')
plt.axis('off')
plt.title('Red Channel')

# Green Channel
plt.subplot(1, 4, 3)
greenChannel = sunflowerImgArray[:, :, 1]
plt.imshow(greenChannel, cmap='gray')
plt.axis('off')
plt.title('Green Channel')

# Blue Channel
plt.subplot(1, 4, 4)
blueChannel = sunflowerImgArray[:, :, 2]
plt.imshow(blueChannel, cmap='gray')
plt.axis('off')
plt.title('Blue Channel')

plt.show()

# %%
# Q5-3

# Make a copy of the image before manipulation
img_copy = sunflowerImgArray.copy()

# Experiment with the coordinates to crop a RoI containing the center of the sunflower

#print(img_copy.shape)
img_copyROI = img_copy[200:500, 190:490]

plt.figure(figsize=(3, 3))
plt.imshow(img_copyROI, cmap='gray')
plt.axis('off')
plt.show()

# replace the pixel values in the RoI to white

img_copy[200:500, 190:490] = 0 * np.ones((300, 300, 3), np.uint8)

# Display the original image and the manipulated image side by side.

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(sunflowerImgArray)
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(img_copy, cmap = 'gray')
plt.axis('off')
plt.title('Manipulated Image')

plt.show()

# %% [markdown]
# #### 6. (15 points) Create a black image of size (500, 500, 3). Write Python statements to complete the following tasks:
#
# 1. Modify the pixels of the black image to display **at least seven different colors**. Be creative with your design. **Your design should be different from the class example.** (10 pts)
# 2. Display both the original black image and the manipulated image side by side. (3 pts)
# 3. Save the manipulated image as **"color_composition.png"** and verify that it appears in your Colab runtime's Files folder. (2 pts)
#
# **Hints:**
# You can search online (e.g., use Google) to find the RGB values for your favorite colors.

# %%
# Q6-1

black_img = np.zeros((500, 500, 3), np.uint8)

color_composition = black_img.copy()

color_composition[40:500, 0:50] = np.array([255, 189, 243]) # Light Pink
color_composition[0:500, 50:100] = np.array([51, 51, 255]) # Some type of Blue
color_composition[20:500, 100:150] = np.array([204, 153, 255]) # Light Purple
color_composition[0:500, 150:200] = np.array([153, 204, 255]) # Light Blue
color_composition[0:500, 200:300] = np.array([255, 0, 0]) # Red
color_composition[30:500, 300:400] = np.array([0, 55, 15]) # A really dark green
color_composition[0:500, 400:500] = np.array([8, 88, 88]) # Some type of greenish Blue

# %%
# Q6-2

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(black_img)
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(color_composition)
plt.axis('off')
plt.title('Manipulated Image')

plt.show()

# %%
# Q6-3

cv2.imwrite('color_composition.png', color_composition)
# Out:
# True

# %% [markdown]
# #### 7. (20 points) Load the **grayscale** image **blurry-moon.tif** into a variable **`moonImg`**. Write Python statements to complete the following tasks:
#
# 1. Print the minimum and maximum pixel values in the image. (4 pts)
# 2. Identify the center pixel of the image and print its pixel value along with the pixel values of its eight surrounding neighbors. (8 pts)
# 3. Modify the image so that pixels within the range [100, 200] are set to white, and all other pixels are set to black. Display both the original image and the manipulated image side by side. (8 pts)
#
# **Hints:**
# 1. Use the functions `np.min()` and `np.max()` to find the minimum and maximum pixel values.
# 2. Use the integer division operator `//` to calculate the coordinates of the center pixel. See the below example.
# 3. To print the center pixel and its neighbors, consider how you would extract a RoI.
# 4. For the final display, ensure that both grayscale images are displayed correctly by using `cmap='gray'`.

# %%
# integer division operator
301 // 2
# Out:
# 150

# %%
# Q7-1

moonImg = cv2.imread('blurry-moon.tif', cv2.IMREAD_GRAYSCALE)

print("Minimum pixel value:", np.min(moonImg))
print("Maximum pixel value:", np.max(moonImg))
# Out:
# Minimum pixel value: 0
# Maximum pixel value: 255

# %%
# Q7-2

height = moonImg.shape[0]
width = moonImg.shape[1]

center_pixel = moonImg[height//2, width//2]
print("Center pixel value:", center_pixel)

upperLeftCorner = moonImg[(height//2)-1, (width//2)-1]
print("Upper left corner pixel value:", upperLeftCorner)
up = moonImg[(height//2)-1, width//2]
print("Upper pixel value:", up)
upperRightCorner = moonImg[(height//2)-1, (width//2)+1]
print("Upper right corner pixel value:", upperRightCorner)

right = moonImg[height//2, (width//2)+1]
print("Right pixel value:", right)
left = moonImg[height//2, (width//2)-1]
print("Left pixel value:", left)

lowerLeftCorner = moonImg[(height//2)+1, (width//2)-1]
print("Lower left corner pixel value:", lowerLeftCorner)
down = moonImg[(height//2)+1, width//2]
print("Lower pixel value:", down)
lowerRightCorner = moonImg[(height//2)+1, (width//2)+1]
print("Lower right corner pixel value:", lowerRightCorner)
# Out:
# Center pixel value: 117
# Upper left corner pixel value: 123
# Upper pixel value: 115
# Upper right corner pixel value: 112
# Right pixel value: 112
# Left pixel value: 122
# Lower left corner pixel value: 119
# Lower pixel value: 117
# Lower right corner pixel value: 113

# %%
# Q7-3

manipulated_moonImg = moonImg.copy()

manipulated_moonImg = np.where((manipulated_moonImg >= 100) & (manipulated_moonImg <= 200), 255, 0)

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(moonImg, cmap = "gray")
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(manipulated_moonImg, cmap = "gray")
plt.axis('off')
plt.title('Manipulated Image')

plt.show()
